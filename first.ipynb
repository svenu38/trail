# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("adult_reconstruction.csv")

# %%
df.dtypes
# Out:
# hours-per-week     int64
# age                int64
# capital-gain       int64
# capital-loss       int64
# workclass         object
# education         object
# education-num      int64
# marital-status    object
# relationship      object
# race              object
# gender            object
# native-country    object
# income             int64
# occupation        object
# dtype: object

# %%
plt.bar(df.index, df['age'], color='skyblue')
plt.xlabel('Index')
plt.ylabel('Age')
plt.title('Bar Chart for Age')
plt.show()

# %%
plt.bar(df.index, df['income'], color='skyblue')
plt.xlabel('Index')
plt.ylabel('income')
plt.title('Bar Chart for income')
plt.show()

# %%
plt.bar(df.index, df['capital-gain'], color='skyblue')
plt.xlabel('Index')
plt.ylabel('capital-gain')
plt.title('Bar Chart for capital-gain')
plt.show()

# %%
df.describe().T
# Out:
#                   count          mean           std    min      25%      50%  \
# hours-per-week  49531.0     40.399184     12.340824    1.0     40.0     40.0
# age             49531.0     38.554320     13.701025   17.0     28.0     37.0
# capital-gain    49531.0   1064.819144   7401.671807    0.0      0.0      0.0
# capital-loss    49531.0     86.285114    400.322887    0.0      0.0      0.0
# education-num   49531.0     10.069795      2.565829    1.0      9.0     10.0
# income          49531.0  33509.843129  27051.436074  107.0  12027.0  26013.0
#
#                     75%      max
# hours-per-week     45.0     99.0
# age                48.0     90.0
# capital-gain        0.0  99999.0
# capital-loss        0.0   4356.0
# education-num      12.0     16.0
# income          48457.5  99999.0

# %%
df.nunique()
# Out:
# hours-per-week       96
# age                  74
# capital-gain        123
# capital-loss         99
# workclass             9
# education            16
# education-num        16
# marital-status        7
# relationship          6
# race                  5
# gender                2
# native-country       42
# income            21230
# occupation           15
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49526    False
# 49527    False
# 49528    False
# 49529    False
# 49530    False
# Length: 49531, dtype: bool

# %%
df[numerical].head().T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/venu/Documents/GitHub/trail/first.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/venu/Documents/GitHub/trail/first.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> df[numerical].head().T
#
# NameError: name 'numerical' is not defined

# %%
def missing (df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values

# %%
missing(df)
# Out:
#                 Missing_Number  Missing_Percent
# hours-per-week               0              0.0
# age                          0              0.0
# capital-gain                 0              0.0
# capital-loss                 0              0.0
# workclass                    0              0.0
# education                    0              0.0
# education-num                0              0.0
# marital-status               0              0.0
# relationship                 0              0.0
# race                         0              0.0
# gender                       0              0.0
# native-country               0              0.0
# income                       0              0.0
# occupation                   0              0.0
